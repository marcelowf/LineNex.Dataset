# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

machine_id_inicio = 21
machine_id_fim = 30
output_final_csv = 'melhores_modelos_finais_arima_sarima.csv'
output_todos_csv = 'todos_modelos_avaliados_arima_sarima.csv'

print("Carregando dados...")
dataset_url = 'https://raw.githubusercontent.com/marcelowf/LineNex.Dataset/main/dataset_preprocessado.csv'
df_full = pd.read_csv(dataset_url, parse_dates=['Timestamp'])

best_param_url = 'https://raw.githubusercontent.com/marcelowf/LineNex.Dataset/main/melhores_modelos_arima_por_maquina.csv'
melhores_arima = pd.read_csv(best_param_url)

melhores_arima = melhores_arima[(melhores_arima['Machine_ID'] >= machine_id_inicio) &
                                 (melhores_arima['Machine_ID'] <= machine_id_fim)]

seasonal_orders = [(1, 1, 1, s) for s in [24, 12, 7]]
resultados_finais, todos_resultados = [], []

for idx, row in melhores_arima.iterrows():
    machine_id = row['Machine_ID']
    variable = row['Variable']
    arima_order = (int(row['p']), int(row['d']), int(row['q']))
    df_machine = df_full[df_full['Machine_ID'] == machine_id].copy()

    series = pd.to_numeric(df_machine[variable], errors='coerce').dropna().reset_index(drop=True)

    if len(series) < 30:
        print(f"[{idx}] Ignorado - Poucos dados para Machine {machine_id}, Variável {variable}")
        continue

    print(f"[{idx}] Avaliando Machine {machine_id}, Variável '{variable}' - ARIMA{arima_order}")

    # ARIMA
    arima_aic = arima_bic = arima_mse = np.inf
    model_arima = None
    try:
        model_arima = ARIMA(series, order=arima_order).fit()
    except Exception as e:
        print(f"Primeira tentativa ARIMA falhou: {e}")
        try:
            model_arima = ARIMA(series, order=arima_order).fit(method="yule_walker", start_params=None)
        except Exception as e2:
            print(f"Segunda tentativa ARIMA falhou: {e2}")
            model_arima = None

    if model_arima:
        arima_aic = model_arima.aic
        arima_bic = model_arima.bic
        try:
            fitted = model_arima.fittedvalues
            min_len = min(len(series), len(fitted))
            arima_mse = mean_squared_error(series[-min_len:], fitted[-min_len:])
        except Exception:
            arima_mse = np.nan

    todos_resultados.append({
        'Machine_ID': machine_id,
        'Variable': variable,
        'Model': 'ARIMA',
        'ARIMA_Order': arima_order,
        'Seasonal_Order': None,
        'AIC': arima_aic,
        'BIC': arima_bic,
        'MSE': arima_mse,
        'n_obs': len(series)
    })

    best_model_type = 'ARIMA'
    best_order = arima_order
    best_seasonal_order = None
    best_aic, best_bic, best_mse = arima_aic, arima_bic, arima_mse

    # SARIMA
    for seasonal_order in seasonal_orders:
        try:
            model_sarima = SARIMAX(series, order=arima_order, seasonal_order=seasonal_order,
                                   enforce_stationarity=False, enforce_invertibility=False).fit(disp=False)
            fitted = model_sarima.fittedvalues
            min_len = min(len(series), len(fitted))
            mse = mean_squared_error(series[-min_len:], fitted[-min_len:])

            todos_resultados.append({
                'Machine_ID': machine_id,
                'Variable': variable,
                'Model': 'SARIMA',
                'ARIMA_Order': arima_order,
                'Seasonal_Order': seasonal_order,
                'AIC': model_sarima.aic,
                'BIC': model_sarima.bic,
                'MSE': mse,
                'n_obs': len(series)
            })

            if model_sarima.aic < best_aic:
                best_model_type = 'SARIMA'
                best_seasonal_order = seasonal_order
                best_aic = model_sarima.aic
                best_bic = model_sarima.bic
                best_mse = mse
        except Exception as e:
            print(f"SARIMA {seasonal_order} falhou: {e}")
            continue

    print(f"Melhor modelo para Machine {machine_id}, Variável '{variable}': {best_model_type} {best_order} {'+ ' + str(best_seasonal_order) if best_seasonal_order else ''} | AIC: {best_aic:.2f}, MSE: {best_mse:.4f}")

    resultados_finais.append({
        'Machine_ID': machine_id,
        'Variable': variable,
        'Best_Model': best_model_type,
        'ARIMA_Order': best_order,
        'Seasonal_Order': best_seasonal_order,
        'AIC': best_aic,
        'BIC': best_bic,
        'MSE': best_mse,
        'n_obs': len(series)
    })

    pd.DataFrame(resultados_finais).replace([np.inf, -np.inf], np.nan).to_csv(output_final_csv, index=False)
    pd.DataFrame(todos_resultados).replace([np.inf, -np.inf], np.nan).to_csv(output_todos_csv, index=False)
    print(f"Dados salvos após Machine {machine_id}")

print("\nProcesso concluído")
# Out:
# Carregando dados...
# [5] Avaliando Machine 29, Variável 'Production_Speed_units_per_hr' - ARIMA(0, 1, 2)
# → Melhor modelo para Machine 29, Variável 'Production_Speed_units_per_hr': SARIMA (0, 1, 2) + (1, 1, 1, 24) | AIC: 25071.54, MSE: 17586.9149
# ✓ Dados salvos após Machine 29
# [6] Avaliando Machine 29, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 1)
# → Melhor modelo para Machine 29, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 1)  | AIC: 743.44, MSE: 0.0840
# ✓ Dados salvos após Machine 29
# [7] Avaliando Machine 29, Variável 'Efficiency_Status' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 29, Variável 'Efficiency_Status': ARIMA (0, 0, 0)  | AIC: 2422.72, MSE: 0.1912
# ✓ Dados salvos após Machine 29
# [8] Avaliando Machine 29, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(3, 0, 2)
# → Melhor modelo para Machine 29, Variável 'Quality_Control_Defect_Rate_%': SARIMA (3, 0, 2) + (1, 1, 1, 24) | AIC: 9994.82, MSE: 8.9458
# ✓ Dados salvos após Machine 29
# [9] Avaliando Machine 29, Variável 'Error_Rate_%' - ARIMA(0, 0, 1)
# → Melhor modelo para Machine 29, Variável 'Error_Rate_%': SARIMA (0, 0, 1) + (1, 1, 1, 24) | AIC: 11613.05, MSE: 20.6623
# ✓ Dados salvos após Machine 29
# [25] Avaliando Machine 21, Variável 'Production_Speed_units_per_hr' - ARIMA(2, 1, 1)
# → Melhor modelo para Machine 21, Variável 'Production_Speed_units_per_hr': SARIMA (2, 1, 1) + (1, 1, 1, 24) | AIC: 25275.82, MSE: 18394.9463
# ✓ Dados salvos após Machine 21
# [26] Avaliando Machine 21, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 21, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 0)  | AIC: 735.77, MSE: 0.0836
# ✓ Dados salvos após Machine 21
# [27] Avaliando Machine 21, Variável 'Efficiency_Status' - ARIMA(2, 0, 3)
# → Melhor modelo para Machine 21, Variável 'Efficiency_Status': ARIMA (2, 0, 3)  | AIC: 2444.73, MSE: 0.1914
# ✓ Dados salvos após Machine 21
# [28] Avaliando Machine 21, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(2, 0, 2)
# → Melhor modelo para Machine 21, Variável 'Quality_Control_Defect_Rate_%': SARIMA (2, 0, 2) + (1, 1, 1, 24) | AIC: 10090.86, MSE: 9.4015
# ✓ Dados salvos após Machine 21
# [29] Avaliando Machine 21, Variável 'Error_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 21, Variável 'Error_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 11667.96, MSE: 21.0025
# ✓ Dados salvos após Machine 21
# [35] Avaliando Machine 23, Variável 'Production_Speed_units_per_hr' - ARIMA(1, 1, 2)
# → Melhor modelo para Machine 23, Variável 'Production_Speed_units_per_hr': SARIMA (1, 1, 2) + (1, 1, 1, 24) | AIC: 25708.27, MSE: 17832.1810
# ✓ Dados salvos após Machine 23
# [36] Avaliando Machine 23, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 23, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 0)  | AIC: 782.57, MSE: 0.0849
# ✓ Dados salvos após Machine 23
# [37] Avaliando Machine 23, Variável 'Efficiency_Status' - ARIMA(3, 0, 2)
# → Melhor modelo para Machine 23, Variável 'Efficiency_Status': ARIMA (3, 0, 2)  | AIC: 2658.55, MSE: 0.2073
# ✓ Dados salvos após Machine 23
# [38] Avaliando Machine 23, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(2, 0, 3)
# → Melhor modelo para Machine 23, Variável 'Quality_Control_Defect_Rate_%': SARIMA (2, 0, 3) + (1, 1, 1, 24) | AIC: 10247.24, MSE: 9.4079
# ✓ Dados salvos após Machine 23
# [39] Avaliando Machine 23, Variável 'Error_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 23, Variável 'Error_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 11897.72, MSE: 20.7048
# ✓ Dados salvos após Machine 23
# [45] Avaliando Machine 24, Variável 'Production_Speed_units_per_hr' - ARIMA(0, 1, 1)
# → Melhor modelo para Machine 24, Variável 'Production_Speed_units_per_hr': SARIMA (0, 1, 1) + (1, 1, 1, 24) | AIC: 24431.27, MSE: 18487.9156
# ✓ Dados salvos após Machine 24
# [46] Avaliando Machine 24, Variável 'Predictive_Maintenance_Score' - ARIMA(3, 0, 2)
# → Melhor modelo para Machine 24, Variável 'Predictive_Maintenance_Score': ARIMA (3, 0, 2)  | AIC: 728.53, MSE: 0.0839
# ✓ Dados salvos após Machine 24
# [47] Avaliando Machine 24, Variável 'Efficiency_Status' - ARIMA(2, 0, 2)
# → Melhor modelo para Machine 24, Variável 'Efficiency_Status': ARIMA (2, 0, 2)  | AIC: 2542.02, MSE: 0.2096
# ✓ Dados salvos após Machine 24
# [48] Avaliando Machine 24, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(1, 0, 2)
# → Melhor modelo para Machine 24, Variável 'Quality_Control_Defect_Rate_%': SARIMA (1, 0, 2) + (1, 1, 1, 24) | AIC: 9652.92, MSE: 8.7674
# ✓ Dados salvos após Machine 24
# [49] Avaliando Machine 24, Variável 'Error_Rate_%' - ARIMA(2, 0, 3)
# → Melhor modelo para Machine 24, Variável 'Error_Rate_%': SARIMA (2, 0, 3) + (1, 1, 1, 24) | AIC: 11263.60, MSE: 20.9567
# ✓ Dados salvos após Machine 24
# [65] Avaliando Machine 22, Variável 'Production_Speed_units_per_hr' - ARIMA(0, 1, 1)
# → Melhor modelo para Machine 22, Variável 'Production_Speed_units_per_hr': SARIMA (0, 1, 1) + (1, 1, 1, 24) | AIC: 24969.70, MSE: 18159.7305
# ✓ Dados salvos após Machine 22
# [66] Avaliando Machine 22, Variável 'Predictive_Maintenance_Score' - ARIMA(2, 0, 2)
# → Melhor modelo para Machine 22, Variável 'Predictive_Maintenance_Score': ARIMA (2, 0, 2)  | AIC: 674.09, MSE: 0.0811
# ✓ Dados salvos após Machine 22
# [67] Avaliando Machine 22, Variável 'Efficiency_Status' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 22, Variável 'Efficiency_Status': ARIMA (0, 0, 0)  | AIC: 2504.41, MSE: 0.2005
# ✓ Dados salvos após Machine 22
# [68] Avaliando Machine 22, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(3, 0, 3)
# → Melhor modelo para Machine 22, Variável 'Quality_Control_Defect_Rate_%': SARIMA (3, 0, 3) + (1, 1, 1, 24) | AIC: 9887.06, MSE: 9.4095
# ✓ Dados salvos após Machine 22
# [69] Avaliando Machine 22, Variável 'Error_Rate_%' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 22, Variável 'Error_Rate_%': SARIMA (2, 1, 3) + (1, 1, 1, 24) | AIC: 11507.52, MSE: 20.6398
# ✓ Dados salvos após Machine 22
# [80] Avaliando Machine 30, Variável 'Production_Speed_units_per_hr' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 30, Variável 'Production_Speed_units_per_hr': SARIMA (2, 1, 3) + (1, 1, 1, 12) | AIC: 25807.41, MSE: 17758.0093
# ✓ Dados salvos após Machine 30
# [81] Avaliando Machine 30, Variável 'Predictive_Maintenance_Score' - ARIMA(1, 0, 0)
# → Melhor modelo para Machine 30, Variável 'Predictive_Maintenance_Score': ARIMA (1, 0, 0)  | AIC: 701.47, MSE: 0.0819
# ✓ Dados salvos após Machine 30
# [82] Avaliando Machine 30, Variável 'Efficiency_Status' - ARIMA(3, 0, 3)
# → Melhor modelo para Machine 30, Variável 'Efficiency_Status': ARIMA (3, 0, 3)  | AIC: 2350.18, MSE: 0.1804
# ✓ Dados salvos após Machine 30
# [83] Avaliando Machine 30, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(1, 0, 1)
# → Melhor modelo para Machine 30, Variável 'Quality_Control_Defect_Rate_%': SARIMA (1, 0, 1) + (1, 1, 1, 24) | AIC: 10211.59, MSE: 9.1903
# ✓ Dados salvos após Machine 30
# [84] Avaliando Machine 30, Variável 'Error_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 30, Variável 'Error_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 11679.86, MSE: 19.4908
# ✓ Dados salvos após Machine 30
# [100] Avaliando Machine 25, Variável 'Production_Speed_units_per_hr' - ARIMA(0, 1, 1)
# → Melhor modelo para Machine 25, Variável 'Production_Speed_units_per_hr': SARIMA (0, 1, 1) + (1, 1, 1, 24) | AIC: 24559.89, MSE: 18137.6127
# ✓ Dados salvos após Machine 25
# [101] Avaliando Machine 25, Variável 'Predictive_Maintenance_Score' - ARIMA(3, 0, 3)
# → Melhor modelo para Machine 25, Variável 'Predictive_Maintenance_Score': ARIMA (3, 0, 3)  | AIC: 723.10, MSE: 0.0834
# ✓ Dados salvos após Machine 25
# [102] Avaliando Machine 25, Variável 'Efficiency_Status' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 25, Variável 'Efficiency_Status': ARIMA (2, 1, 3)  | AIC: 2378.34, MSE: 0.1916
# ✓ Dados salvos após Machine 25
# [103] Avaliando Machine 25, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 25, Variável 'Quality_Control_Defect_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 9732.05, MSE: 9.0963
# ✓ Dados salvos após Machine 25
# [104] Avaliando Machine 25, Variável 'Error_Rate_%' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 25, Variável 'Error_Rate_%': SARIMA (2, 1, 3) + (1, 1, 1, 24) | AIC: 11365.45, MSE: 20.5379
# ✓ Dados salvos após Machine 25
# [110] Avaliando Machine 27, Variável 'Production_Speed_units_per_hr' - ARIMA(2, 1, 2)
# → Melhor modelo para Machine 27, Variável 'Production_Speed_units_per_hr': SARIMA (2, 1, 2) + (1, 1, 1, 24) | AIC: 24075.79, MSE: 18440.8945
# ✓ Dados salvos após Machine 27
# [111] Avaliando Machine 27, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 27, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 0)  | AIC: 713.47, MSE: 0.0841
# ✓ Dados salvos após Machine 27
# [112] Avaliando Machine 27, Variável 'Efficiency_Status' - ARIMA(1, 0, 3)
# → Melhor modelo para Machine 27, Variável 'Efficiency_Status': ARIMA (1, 0, 3)  | AIC: 2418.26, MSE: 0.2002
# ✓ Dados salvos após Machine 27
# [113] Avaliando Machine 27, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 27, Variável 'Quality_Control_Defect_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 9651.85, MSE: 9.6854
# ✓ Dados salvos após Machine 27
# [114] Avaliando Machine 27, Variável 'Error_Rate_%' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 27, Variável 'Error_Rate_%': SARIMA (2, 1, 3) + (1, 1, 1, 24) | AIC: 11073.18, MSE: 20.2117
# ✓ Dados salvos após Machine 27
# [120] Avaliando Machine 28, Variável 'Production_Speed_units_per_hr' - ARIMA(2, 1, 3)
# → Melhor modelo para Machine 28, Variável 'Production_Speed_units_per_hr': SARIMA (2, 1, 3) + (1, 1, 1, 12) | AIC: 25405.96, MSE: 17427.3411
# ✓ Dados salvos após Machine 28
# [121] Avaliando Machine 28, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 28, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 0)  | AIC: 769.85, MSE: 0.0851
# ✓ Dados salvos após Machine 28
# [122] Avaliando Machine 28, Variável 'Efficiency_Status' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 28, Variável 'Efficiency_Status': ARIMA (0, 0, 0)  | AIC: 2384.60, MSE: 0.1872
# ✓ Dados salvos após Machine 28
# [123] Avaliando Machine 28, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(2, 0, 3)
# → Melhor modelo para Machine 28, Variável 'Quality_Control_Defect_Rate_%': SARIMA (2, 0, 3) + (1, 1, 1, 24) | AIC: 9995.74, MSE: 9.1061
# ✓ Dados salvos após Machine 28
# [124] Avaliando Machine 28, Variável 'Error_Rate_%' - ARIMA(3, 0, 3)
# → Melhor modelo para Machine 28, Variável 'Error_Rate_%': SARIMA (3, 0, 3) + (1, 1, 1, 24) | AIC: 11597.45, MSE: 22.2774
# ✓ Dados salvos após Machine 28
# [170] Avaliando Machine 26, Variável 'Production_Speed_units_per_hr' - ARIMA(2, 0, 3)
# → Melhor modelo para Machine 26, Variável 'Production_Speed_units_per_hr': SARIMA (2, 0, 3) + (1, 1, 1, 24) | AIC: 25416.52, MSE: 21174.3531
# ✓ Dados salvos após Machine 26
# [171] Avaliando Machine 26, Variável 'Predictive_Maintenance_Score' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 26, Variável 'Predictive_Maintenance_Score': ARIMA (0, 0, 0)  | AIC: 654.62, MSE: 0.0803
# ✓ Dados salvos após Machine 26
# [172] Avaliando Machine 26, Variável 'Efficiency_Status' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 26, Variável 'Efficiency_Status': ARIMA (0, 0, 0)  | AIC: 2543.64, MSE: 0.2010
# ✓ Dados salvos após Machine 26
# [173] Avaliando Machine 26, Variável 'Quality_Control_Defect_Rate_%' - ARIMA(1, 1, 2)
# → Melhor modelo para Machine 26, Variável 'Quality_Control_Defect_Rate_%': SARIMA (1, 1, 2) + (1, 1, 1, 24) | AIC: 9961.21, MSE: 8.5748
# ✓ Dados salvos após Machine 26
# [174] Avaliando Machine 26, Variável 'Error_Rate_%' - ARIMA(0, 0, 0)
# → Melhor modelo para Machine 26, Variável 'Error_Rate_%': SARIMA (0, 0, 0) + (1, 1, 1, 24) | AIC: 11665.86, MSE: 20.2356
# ✓ Dados salvos após Machine 26
#
# ✅ Processo concluído com sucesso!
# - Melhores modelos salvos em: 'melhores_modelos_finais_arima_sarima.csv'
# - Todos os modelos testados salvos em: 'todos_modelos_avaliados_arima_sarima.csv'
